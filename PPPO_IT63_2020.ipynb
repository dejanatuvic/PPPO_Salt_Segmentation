# %% [markdown]
# <a href="https://colab.research.google.com/github/dejanatuvic/PPPO_Salt_Segmentation/blob/main/PPPO_IT63_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fakultet tehničkih nauka - Univerzitet u Novom Sadu**
#
# **Smer**: Inženjerstvo informacionih sistema
#
# **Predmet**: Principi prezentacije i prepoznavanja oblika
#
# **Tema**: Segmentacija soli
#
# **Student**: Dejana Tuvić IT63/2020

# %% [markdown]
# # **Uvod**
#
# U okviru predmeta 'Principi prezentacije i prepoznavanja oblika' za potrebe projektnog zadatka obrađen je skup podataka nad kojim je vršen proces segmentacije. Skup podataka predstavlja set slika koje su predmet segmentacije. Segmentacija je jedna od tehnika digitalne obrade slika u oblastima računarske vizije i dubokog učenja.
#
# Projekat obuhvata teorijski deo u okviru kog su predstavljeni osnovni koncepti segmentacije, metode, algoritmi i tehnike, i praktični deo koji podrazumeva učitavanje podataka, vizelizaciju, izradu modela, treniranje i evaluaciju testiranja.

# %% [markdown]
# # **Segmentacija**
#
# Segmentacija slika je proces razdvajanja ili označavanja različitih objekata ili regija unutar slike, odnosno grupisanje piksela slike kako bi se bolje razumela njena struktura. Ova tehnika ima široku primenu u različitim područjima, uključujući medicinsku dijagnostiku, automatsku vožnju, analizu satelitskih slika i mnoge druge.
#
# Neki od osnovnih koraka i tehnika koje se često koriste u procesu segmentacije slika su:
#
# 1.   Pretprocesiranje slike: Pre nego što počnete sa segmentacijom, slika se obično podvrgava pretprocesiranju kako bi se poboljšao kvalitet i uklonili nepotrebni šumovi. Ovo može uključivati ​​korake kao što su glačanje (*engl. smoothing*) za uklanjanje šuma i poboljšanje kontrasta.
#
# 2.   Izbor pristupa segmentaciji:
#
#   Segmentacija rubova (*engl. edge-based segmentation*): Ova tehnika fokusira se na identifikaciju rubova i kontura objekata u slici. Rubovi često označavaju granice između različitih regija u slici.
#
#   Segmentacija na temelju boja (*engl. color-based segmentation*): Ova metoda koristi informacije o bojama kako bi razdvojila objekte s različitim bojama ili intenzitetima.
#
#   Segmentacija na temelju regija (*engl. region-based segmentation*): Ovde se slika deli na različite regije koje dele slične karakteristike, poput boje ili teksture.
#
# 3.   Primena algoritama za segmentaciju: Nakon što je pristup segmentaciji odabran, koriste se odgovarajući algoritmi. Primeri uključuju:
#   Metoda otsu (*engl. Otsu's method*): Ova metoda koristi analizu histograma boje ili intenziteta kako bi pronašla prag vrednosti koja razdvaja različite regije.
#
#   Metoda k-srednjih vrednosti (*engl. k-means clustering*): Ova tehnika grupira piksele slika u k skupina na temelju njihovih boja ili karakteristika, često se koristi za segmentaciju na temelju boje.
#
#   Metoda rasta regije (*engl. region growing*): Ova metoda počinje s pojedinim pikselima i postupno rasteže regiju dodavanjem susednih piksela koji dele slične karakteristike.
#
# 4.   Ocenjivanje i optimizacija: Nakon što se segmentacija sprovede, važno je proceniti njenu tačnost i kvalitet. Mogu se koristiti različite metrike, poput Indeksa sličnosti struktura (*engl. Structural Similarity Index - SSIM*) ili Indeksa Jaccard (*engl. Jaccard Index*), kako bi se procenila sličnost između stvarnih i segmentiranih regija. U nekim slučajevima može biti potrebno ručno prilagoditi ili optimizovati segmentaciju.
#
#
# 5.   Postprocesiranje: Nakon što se dobiju segmentirane regije, mogu se primeniti dodatni postupci poput uklanjanja malih nepovezanih komponenti ili glačanja granica kako bi se dobila glatka i čista segmentacija.
#
#
# # **Najkorišćenije tehnike**
#
# **Tehnika pragova** (*engl. Thresholding*) - Ova tehnika je jednostavna i često se koristi kada su objekti i pozadina dobro odvojeni po intenzitetu. Postavljanjem praga, određuje se granica između objekata i pozadine. Pikseli sa vrednostima iznad praga se klasifikuju kao objekti, dok se pikseli ispod praga klasifikuju kao pozadina. Prag se može postaviti ručno ili automatski, na primer, korišćenjem OTSU metode za automatsko određivanje praga.
#
# **Tehnika klasterovanja** (*engl. Clustering*) - Klasterovanje je tehnika grupisanja piksela na osnovu sličnosti u prostoru karakteristika. K-means algoritam je jedan od najpoznatijih algoritama klasterovanja koji se koristi za segmentaciju slika. Algoritam iterativno grupiše piksele u K klastera tako da se minimizuje suma kvadrata udaljenosti između piksela i centara klastera. Ova tehnika je posebno korisna kada se želi segmentirati slika na osnovu boje ili intenziteta.
#
# **Tehnika preklapanja regiona** (*engl. Region merging/splitting*) - Ova tehnika se koristi za spajanje ili razdvajanje susednih regiona na slici na osnovu njihove sličnosti ili različitosti. Algoritam rasta regiona (*region growing*) počinje sa pojedinačnim pikselom ili malom grupom piksela i proširuje region na susedne piksele koji imaju slične karakteristike. Algoritam razdvajanja-regija (*region splitting*) deli početni region na manje regione na osnovu razlika u karakteristikama. Ova tehnika se često koristi za segmentaciju objekata koji su povezani ili delimično preklapaju.
#
# **Tehnika ivica** (*engl. Edge-based methods*): Ova tehnika koristi informacije o intenzitetu piksela kako bi se identifikovale ivice objekata na slici. Canny algoritam je jedan od najpoznatijih algoritama za otkrivanje ivica. Ovaj algoritam identifikuje značajne promene intenziteta piksela i vrši postupak filtriranja i povezivanja ivica kako bi se dobio tačan prikaz ivica objekata na slici. Ove ivice se zatim mogu koristiti za segmentaciju.
#
# Svaka od ovih tehnika ima svoje prednosti i ograničenja, i izbor tehnike zavisi od specifičnosti problema i prirode podataka koji se obrađuju. Takođe, u nekim slučajevima se kombinuju više tehnika segmentacije kako bi se postigli što bolji rezultati.

# %% [markdown]
# # **Zaključak**
#
# Projekat je doprineo boljem razumevanju konkretne oblasti.. Glavni cilj je bio što bolje odrediti segmente prisustva soli u zadatom skupu podataka što se može primeniti i na detekciju različitih oblasti.
#
# Svakako ovo istraživanje predstavlja deo mogućnosti budućih tehnologija ali je značajni početak istraživanja koji može doprineti daljem širenju i nadogradnji ove vrste segmentacije.

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.7.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1g3Jv9jOPbx0fu27rrpMzo_ahwXjVrWY_/view?usp=sharing
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1g3Jv9jOPbx0fu27rrpMzo_ahwXjVrWY_
# From (redirected): https://drive.google.com/uc?id=1g3Jv9jOPbx0fu27rrpMzo_ahwXjVrWY_&confirm=t&uuid=1f5691b8-0bf3-49ec-a115-e7adbbae23e6
# To: /content/Salt_Segmentation.zip
# 100% 466M/466M [00:16<00:00, 28.3MB/s]

# %%
# !unzip Salt_Segmentation.zip
# Out:
# Archive:  Salt_Segmentation.zip
#   inflating: competition_data.zip
#   inflating: depths.csv
#   inflating: flamingo.zip
#   inflating: sample_submission.csv
#   inflating: test.zip
#   inflating: train.csv
#   inflating: train.zip

# %%
# !mkdir -p /content/Salt_Segmentation/train
# !unzip train.zip -d /content/Salt_Segmentation/train
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Salt_Segmentation/train/images/d80ead8703.png
#   inflating: /content/Salt_Segmentation/train/images/b012e9ebb0.png
#   inflating: /content/Salt_Segmentation/train/images/d3034e7a60.png
#   inflating: /content/Salt_Segmentation/train/images/ae2ef70d51.png
#   inflating: /content/Salt_Segmentation/train/images/1af44a9db0.png
#   inflating: /content/Salt_Segmentation/train/images/41cfd4b320.png
#   inflating: /content/Salt_Segmentation/train/images/853e89d0d3.png
#   inflating: /content/Salt_Segmentation/train/images/2a484baa26.png
#   inflating: /content/Salt_Segmentation/train/images/92e617896e.png
#   inflating: /content/Salt_Segmentation/train/images/b70f0ab0c2.png
#   inflating: /content/Salt_Segmentation/train/images/e8757626a1.png
#   inflating: /content/Salt_Segmentation/train/images/6a3d92ce59.png
#   inflating: /content/Salt_Segmentation/train/images/127ef4105f.png
#   inflating: /content/Salt_Segmentation/train/images/d21012f5c1.png
#   inflating: /content/Salt_Segmentation/train/images/1cb9549d2c.png
#   inflating: /content/Salt_Segmentation/train/images/e030bdae65.png
#   inflating: /content/Salt_Segmentation/train/images/0cf7155eb6.png
#   inflating: /content/Salt_Segmentation/train/images/badb3ea766.png
#   inflating: /content/Salt_Segmentation/train/images/9bd58061d6.png
#   inflating: /content/Salt_Segmentation/train/images/2b1e71c2a3.png
#   inflating: /content/Salt_Segmentation/train/images/28d42de29f.png
#   inflating: /content/Salt_Segmentation/train/images/10833853b3.png
#   inflating: /content/Salt_Segmentation/train/images/ef13247eed.png
#   inflating: /content/Salt_Segmentation/train/images/bce104494c.png
#   inflating: /content/Salt_Segmentation/train/images/c8ce151a18.png
#   inflating: /content/Salt_Segmentation/train/images/302ea1ac81.png
#   inflating: /content/Salt_Segmentation/train/images/59b1bac5d5.png
#   inflating: /content/Salt_Segmentation/train/images/a3e0a0c779.png
#   inflating: /content/Salt_Segmentation/train/images/be565e046b.png
#   inflating: /content/Salt_Segmentation/train/images/e39ded223d.png
#   inflating: /content/Salt_Segmentation/train/images/9eaf536a63.png
#   inflating: /content/Salt_Segmentation/train/images/568d119e66.png
#   inflating: /content/Salt_Segmentation/train/images/5448c46aac.png
#   inflating: /content/Salt_Segmentation/train/images/452b06b003.png
#   inflating: /content/Salt_Segmentation/train/images/a8ef242dfd.png
#   inflating: /content/Salt_Segmentation/train/images/cdf9422054.png
#   inflating: /content/Salt_Segmentation/train/images/5bb48ef0ea.png
#   inflating: /content/Salt_Segmentation/train/images/bfbb9b9149.png
#   inflating: /content/Salt_Segmentation/train/images/fc87224914.png
#   inflating: /content/Salt_Segmentation/train/images/157b2aa3e0.png
#   inflating: /content/Salt_Segmentation/train/images/cb2c20898a.png
#   inflating: /content/Salt_Segmentation/train/images/d71e91efc0.png
#   inflating: /content/Salt_Segmentation/train/images/ca6bdbc405.png
#   inflating: /content/Salt_Segmentation/train/images/876e6423e6.png
#   inflating: /content/Salt_Segmentation/train/images/851a37ac37.png
#   inflating: /content/Salt_Segmentation/train/images/85fe62d2d6.png
#   inflating: /content/Salt_Segmentation/train/images/0497f2d447.png
#   inflating: /content/Salt_Segmentation/train/images/10aa115164.png
#   inflating: /content/Salt_Segmentation/train/images/d6471dc0a3.png
#   inflating: /content/Salt_Segmentation/train/images/9722dedee7.png
#   inflating: /content/Salt_Segmentation/train/images/18f3626b0f.png
#   inflating: /content/Salt_Segmentation/train/images/2388b3eb40.png
#   inflating: /content/Salt_Segmentation/train/images/3525fcea1e.png
#   inflating: /content/Salt_Segmentation/train/images/b6c52b4a53.png
#   inflating: /content/Salt_Segmentation/train/images/04234be388.png
#   inflating: /content/Salt_Segmentation/train/images/68d00224e0.png
#   inflating: /content/Salt_Segmentation/train/images/e0cfbbcb0c.png
#   inflating: /content/Salt_Segmentation/train/images/7738fbabca.png
#   inflating: /content/Salt_Segmentation/train/images/51179a1815.png
#   inflating: /content/Salt_Segmentation/train/images/a32a4a2256.png
#   inflating: /content/Salt_Segmentation/train/images/269b6cad0d.png
#   inflating: /content/Salt_Segmentation/train/images/4e961dd0ed.png
#   inflating: /content/Salt_Segmentation/train/images/cf7abfc8bb.png
#   inflating: /content/Salt_Segmentation/train/images/5e98f349f3.png
#   inflating: /content/Salt_Segmentation/train/images/2fbde8630d.png
#   inflating: /content/Salt_Segmentation/train/images/a3605816c1.png
#   inflating: /content/Salt_Segmentation/train/images/9d354bc9e7.png
#   inflating: /content/Salt_Segmentation/train/images/5ff89814f5.png
#   inflating: /content/Salt_Segmentation/train/images/fa2ebd1083.png
#   inflating: /content/Salt_Segmentation/train/images/d4d964f62d.png
#   inflating: /content/Salt_Segmentation/train/images/ef51bbcde7.png
#   inflating: /content/Salt_Segmentation/train/images/164873b51f.png
#   inflating: /content/Salt_Segmentation/train/images/f57e741b5b.png
#   inflating: /content/Salt_Segmentation/train/images/4433b159db.png
#   inflating: /content/Salt_Segmentation/train/images/ec542d0719.png
#   inflating: /content/Salt_Segmentation/train/images/6c6c1cbae9.png
#   inflating: /content/Salt_Segmentation/train/images/4630209118.png
#   inflating: /content/Salt_Segmentation/train/images/39cd06da7d.png
#   inflating: /content/Salt_Segmentation/train/images/b93d143e4b.png
#   inflating: /content/Salt_Segmentation/train/images/ed46821aa5.png
#   inflating: /content/Salt_Segmentation/train/images/885c2a90f5.png
#   inflating: /content/Salt_Segmentation/train/images/1c687fea93.png
#   inflating: /content/Salt_Segmentation/train/images/bc3f2b82ec.png
#   inflating: /content/Salt_Segmentation/train/images/bdb9ba462f.png
#   inflating: /content/Salt_Segmentation/train/images/92107f9559.png
#   inflating: /content/Salt_Segmentation/train/images/40a571cf0f.png
#   inflating: /content/Salt_Segmentation/train/images/5b28c5ba50.png
#   inflating: /content/Salt_Segmentation/train/images/57ff97666d.png
#   inflating: /content/Salt_Segmentation/train/images/34bfcfa11b.png
#   inflating: /content/Salt_Segmentation/train/images/4fbda008c7.png
#   inflating: /content/Salt_Segmentation/train/images/53de66df2a.png
#   inflating: /content/Salt_Segmentation/train/images/4d341171a4.png
#   inflating: /content/Salt_Segmentation/train/images/c0565001a3.png
#   inflating: /content/Salt_Segmentation/train/images/941d0865da.png
#   inflating: /content/Salt_Segmentation/train/images/6e691f1825.png
#   inflating: /content/Salt_Segmentation/train/images/bec8f132d0.png
#   inflating: /content/Salt_Segmentation/train/images/f3220c3590.png
#   inflating: /content/Salt_Segmentation/train/images/84bd944c62.png
#   inflating: /content/Salt_Segmentation/train/images/6b2f7ba83d.png
#   inflating: /content/Salt_Segmentation/train/images/254efd9043.png
#   inflating: /content/Salt_Segmentation/train/images/d606f4a578.png
#   inflating: /content/Salt_Segmentation/train/images/40a7f422e2.png
#   inflating: /content/Salt_Segmentation/train/images/106e4043ba.png
#   inflating: /content/Salt_Segmentation/train/images/465463b009.png
#   inflating: /content/Salt_Segmentation/train/images/287aea3a3b.png
#   inflating: /content/Salt_Segmentation/train/images/e37a3da5b2.png
#   inflating: /content/Salt_Segmentation/train/images/b9f3886670.png
#   inflating: /content/Salt_Segmentation/train/images/9ea0525027.png
#   inflating: /content/Salt_Segmentation/train/images/c3a963f5e3.png
#   inflating: /content/Salt_Segmentation/train/images/dccd2d9d48.png
#   inflating: /content/Salt_Segmentation/train/images/b92b11b3a4.png
#   inflating: /content/Salt_Segmentation/train/images/d800abe6a4.png
#   inflating: /content/Salt_Segmentation/train/images/5948185d4d.png
#   inflating: /content/Salt_Segmentation/train/images/c092a99d23.png
#   inflating: /content/Salt_Segmentation/train/images/db5bf853fc.png
#   inflating: /content/Salt_Segmentation/train/images/4c7e3c71e6.png
#   inflating: /content/Salt_Segmentation/train/images/dae1555fbf.png
#   inflating: /content/Salt_Segmentation/train/images/7b2032d7d1.png
#   inflating: /content/Salt_Segmentation/train/images/6092afaec7.png
#   inflating: /content/Salt_Segmentation/train/images/d6b87a521f.png
#   inflating: /content/Salt_Segmentation/train/images/99aefa9443.png
#   inflating: /content/Salt_Segmentation/train/images/4e86258646.png
#   inflating: /content/Salt_Segmentation/train/images/fbf380831b.png
#   inflating: /content/Salt_Segmentation/train/images/d0eb51a04f.png
#   inflating: /content/Salt_Segmentation/train/images/40fbc03558.png
#   inflating: /content/Salt_Segmentation/train/images/7a2eebff84.png
#   inflating: /content/Salt_Segmentation/train/images/6a6ebb2255.png
#   inflating: /content/Salt_Segmentation/train/images/5a3c38104c.png
#   inflating: /content/Salt_Segmentation/train/images/9fdb6afc56.png
#   inflating: /content/Salt_Segmentation/train/images/9f7e064e9f.png
#   inflating: /content/Salt_Segmentation/train/images/43a1dbb062.png
#   inflating: /content/Salt_Segmentation/train/images/0df9f16bc9.png
#   inflating: /content/Salt_Segmentation/train/images/99405de5c5.png
#   inflating: /content/Salt_Segmentation/train/images/b9c2f9550a.png
#   inflating: /content/Salt_Segmentation/train/images/e3755d5769.png
#   inflating: /content/Salt_Segmentation/train/images/24a38972a3.png
#   inflating: /content/Salt_Segmentation/train/images/a653a50dc4.png
#   inflating: /content/Salt_Segmentation/train/images/114daa1bed.png
#   inflating: /content/Salt_Segmentation/train/images/aa56279e8f.png
#   inflating: /content/Salt_Segmentation/train/images/7361f4e5bc.png
#   inflating: /content/Salt_Segmentation/train/images/4ee4b3485e.png
#   inflating: /content/Salt_Segmentation/train/images/b942b38a45.png
#   inflating: /content/Salt_Segmentation/train/images/a87eb66a65.png
#   inflating: /content/Salt_Segmentation/train/images/fff2abcaf9.png
#   inflating: /content/Salt_Segmentation/train/images/b552fb0d9d.png
#   inflating: /content/Salt_Segmentation/train/images/a5d188bbd7.png
#   inflating: /content/Salt_Segmentation/train/images/9a478d8cf2.png
#   inflating: /content/Salt_Segmentation/train/images/44ac5b2526.png
#   inflating: /content/Salt_Segmentation/train/images/a43ca2ef73.png
#   inflating: /content/Salt_Segmentation/train/images/505483d249.png
#   inflating: /content/Salt_Segmentation/train/images/34f61e9a54.png
#   inflating: /content/Salt_Segmentation/train/images/824152cf1c.png
#   inflating: /content/Salt_Segmentation/train/images/3c2ea1a63f.png
#   inflating: /content/Salt_Segmentation/train/images/24cb80b5da.png
#   inflating: /content/Salt_Segmentation/train/images/f5ffe74512.png
#   inflating: /content/Salt_Segmentation/train/images/a05da102a2.png
#   inflating: /content/Salt_Segmentation/train/images/06a361fc57.png
#   inflating: /content/Salt_Segmentation/train/images/437fbb64d4.png
#   inflating: /content/Salt_Segmentation/train/images/740e4ce45d.png
#   inflating: /content/Salt_Segmentation/train/images/b7dc0d87fd.png
#   inflating: /content/Salt_Segmentation/train/images/8b0478ed02.png
#   inflating: /content/Salt_Segmentation/train/images/d73e3ccdec.png
#   inflating: /content/Salt_Segmentation/train/images/14da113475.png
#   inflating: /content/Salt_Segmentation/train/images/7b0c7e28f0.png
#   inflating: /content/Salt_Segmentation/train/images/9d5d4bf0f1.png
#   inflating: /content/Salt_Segmentation/train/images/4b522e501e.png
#   inflating: /content/Salt_Segmentation/train/images/29a1b18e79.png
#   inflating: /content/Salt_Segmentation/train/images/2356ec6570.png
#   inflating: /content/Salt_Segmentation/train/images/96f8fd0d4b.png
#   inflating: /content/Salt_Segmentation/train/images/2596227117.png
#   inflating: /content/Salt_Segmentation/train/images/e51bea30d0.png
#   inflating: /content/Salt_Segmentation/train/images/a8e4e6ddec.png
#   inflating: /content/Salt_Segmentation/train/images/cc876896b5.png
#   inflating: /content/Salt_Segmentation/train/images/7c0b76979f.png
#   inflating: /content/Salt_Segmentation/train/images/9befc65890.png
#   inflating: /content/Salt_Segmentation/train/images/e0bde1cf11.png
#   inflating: /content/Salt_Segmentation/train/images/ce0e9def63.png
#   inflating: /content/Salt_Segmentation/train/images/6f78817a2d.png
#   inflating: /content/Salt_Segmentation/train/images/7796858a9b.png
#   inflating: /content/Salt_Segmentation/train/images/380ff30e30.png
#   inflating: /content/Salt_Segmentation/train/images/8f16b2685d.png
#   inflating: /content/Salt_Segmentation/train/images/b172bd2032.png
#   inflating: /content/Salt_Segmentation/train/images/cadb46b378.png
#   inflating: /content/Salt_Segmentation/train/images/a18073f2a2.png
#   inflating: /content/Salt_Segmentation/train/images/961b1310e9.png
#   inflating: /content/Salt_Segmentation/train/images/9c4c524983.png
#   inflating: /content/Salt_Segmentation/train/images/0c600207b1.png
#   inflating: /content/Salt_Segmentation/train/images/d553c91194.png
#   inflating: /content/Salt_Segmentation/train/images/77608c7770.png
#   inflating: /content/Salt_Segmentation/train/images/3634f29aac.png
#   inflating: /content/Salt_Segmentation/train/images/7568a9474e.png
#   inflating: /content/Salt_Segmentation/train/images/c387a012fc.png
#   inflating: /content/Salt_Segmentation/train/images/bb63bcb48a.png
#   inflating: /content/Salt_Segmentation/train/images/efc705478f.png
#   inflating: /content/Salt_Segmentation/train/images/6e3634da35.png
#   inflating: /content/Salt_Segmentation/train/images/d859ee2145.png
#   inflating: /content/Salt_Segmentation/train/images/9dcb043fa9.png
#   inflating: /content/Salt_Segmentation/train/images/c32752c00f.png
#   inflating: /content/Salt_Segmentation/train/images/918548e472.png
#   inflating: /content/Salt_Segmentation/train/images/4b9b8c2e44.png
#   inflating: /content/Salt_Segmentation/train/images/d765e53b37.png
#   inflating: /content/Salt_Segmentation/train/images/6ec6e26ddd.png
#   inflating: /content/Salt_Segmentation/train/images/97515a958d.png
#   inflating: /content/Salt_Segmentation/train/images/13f448be07.png
#   inflating: /content/Salt_Segmentation/train/images/2af3c055b2.png
#   inflating: /content/Salt_Segmentation/train/images/2e8bf3f7b3.png
#   inflating: /content/Salt_Segmentation/train/images/20ed65cbf8.png
#   inflating: /content/Salt_Segmentation/train/images/3c35e3ad94.png
#   inflating: /content/Salt_Segmentation/train/images/6994342067.png
#   inflating: /content/Salt_Segmentation/train/images/59ceec4f7c.png
#   inflating: /content/Salt_Segmentation/train/images/4e47ff086f.png
#   inflating: /content/Salt_Segmentation/train/images/1ff0aa7f05.png
#   inflating: /content/Salt_Segmentation/train/images/c60eaa0c75.png
#   inflating: /content/Salt_Segmentation/train/images/a6a3383416.png
#   inflating: /content/Salt_Segmentation/train/images/457f80b1c5.png
#   inflating: /content/Salt_Segmentation/train/images/9736389261.png
#   inflating: /content/Salt_Segmentation/train/images/e1921d9a0d.png
#   inflating: /content/Salt_Segmentation/train/images/c1190c9c37.png
#   inflating: /content/Salt_Segmentation/train/images/571e63d0bc.png
#   inflating: /content/Salt_Segmentation/train/images/a536f382ec.png
#   inflating: /content/Salt_Segmentation/train/images/e340e7bfca.png
#   inflating: /content/Salt_Segmentation/train/images/0429d9759b.png
#   inflating: /content/Salt_Segmentation/train/images/22398d77b8.png
#   inflating: /content/Salt_Segmentation/train/images/f0d15c63c5.png
#   inflating: /content/Salt_Segmentation/train/images/d2522cfc93.png
#   inflating: /content/Salt_Segmentation/train/images/eead2fc101.png
#   inflating: /content/Salt_Segmentation/train/images/19843b4e95.png
#   inflating: /content/Salt_Segmentation/train/images/9258e48804.png
#   inflating: /content/Salt_Segmentation/train/images/ddcb1ad560.png
#   inflating: /content/Salt_Segmentation/train/images/fdc28cafdc.png
#   inflating: /content/Salt_Segmentation/train/images/1f73caa937.png
#   inflating: /content/Salt_Segmentation/train/images/58a51c861e.png
#   inflating: /content/Salt_Segmentation/train/images/b1be1fa682.png
#   inflating: /content/Salt_Segmentation/train/images/a4e8ba21d1.png
#   inflating: /content/Salt_Segmentation/train/images/c0aa0c7b66.png
#   inflating: /content/Salt_Segmentation/train/images/7deaf30c4a.png
#   inflating: /content/Salt_Segmentation/train/images/cbad345488.png
#   inflating: /content/Salt_Segmentation/train/images/93f7759d52.png
#   inflating: /content/Salt_Segmentation/train/images/f625984494.png
#   inflating: /content/Salt_Segmentation/train/images/5326fad561.png
#   inflating: /content/Salt_Segmentation/train/images/5f1df5e4a8.png
#   inflating: /content/Salt_Segmentation/train/images/6348c487a4.png
#   inflating: /content/Salt_Segmentation/train/images/9b656c339a.png
#   inflating: /content/Salt_Segmentation/train/images/e82421363e.png
#   inflating: /content/Salt_Segmentation/train/images/dc4a1c9a30.png
#   inflating: /content/Salt_Segmentation/train/images/253ee294d9.png
#   inflating: /content/Salt_Segmentation/train/images/dde0ee264b.png
#   inflating: /content/Salt_Segmentation/train/images/94b3a9ed9c.png
#   inflating: /content/Salt_Segmentation/train/images/816c9d6d5d.png
#   inflating: /content/Salt_Segmentation/train/images/3c66e5ab54.png
#   inflating: /content/Salt_Segmentation/train/images/ebcd41b5f1.png
#   inflating: /content/Salt_Segmentation/train/images/1739b1634d.png
#   inflating: /content/Salt_Segmentation/train/images/8cf3a6a6f5.png
#   inflating: /content/Salt_Segmentation/train/images/e185ab5dc1.png
#   inflating: /content/Salt_Segmentation/train/images/553733b17b.png
#   inflating: /content/Salt_Segmentation/train/images/8b5757d8ee.png
#   inflating: /content/Salt_Segmentation/train/images/dc710565e6.png
#   inflating: /content/Salt_Segmentation/train/images/48db3b8c5f.png
#   inflating: /content/Salt_Segmentation/train/images/e0dade9896.png
#   inflating: /content/Salt_Segmentation/train/images/a076699b79.png
#   inflating: /content/Salt_Segmentation/train/images/d465b396f2.png
#   inflating: /content/Salt_Segmentation/train/images/1017084680.png
#   inflating: /content/Salt_Segmentation/train/images/e80ac14b0f.png
#   inflating: /content/Salt_Segmentation/train/images/a2a012f128.png
#   inflating: /content/Salt_Segmentation/train/images/f5b2861c9b.png
#   inflating: /content/Salt_Segmentation/train/images/abe74273c8.png
#   inflating: /content/Salt_Segmentation/train/images/2bca4fe522.png
#   inflating: /content/Salt_Segmentation/train/images/91ea3f1227.png
#   inflating: /content/Salt_Segmentation/train/images/62aad7556c.png
#   inflating: /content/Salt_Segmentation/train/images/d2f131dba8.png
#   inflating: /content/Salt_Segmentation/train/images/c33faa5d81.png
#   inflating: /content/Salt_Segmentation/train/images/26ec6ef9df.png
#   inflating: /content/Salt_Segmentation/train/images/c47c5ea1c3.png
#   inflating: /content/Salt_Segmentation/train/images/a7254b3aa6.png
#   inflating: /content/Salt_Segmentation/train/images/89dba191b1.png
#   inflating: /content/Salt_Segmentation/train/images/63d3cf63be.png
#   inflating: /content/Salt_Segmentation/train/images/57302cf4b6.png
#   inflating: /content/Salt_Segmentation/train/images/a141ed0c99.png
#   inflating: /content/Salt_Segmentation/train/images/548887f17d.png
#   inflating: /content/Salt_Segmentation/train/images/cf11876547.png
#   inflating: /content/Salt_Segmentation/train/images/0cc1d0e4c4.png
#   inflating: /content/Salt_Segmentation/train/images/f87365827d.png
#   inflating: /content/Salt_Segmentation/train/images/99d7f0c538.png
#   inflating: /content/Salt_Segmentation/train/images/3f5adbdcc7.png
#   inflating: /content/Salt_Segmentation/train/images/bd2a0b256c.png
#   inflating: /content/Salt_Segmentation/train/images/a4fb7072d6.png
#   inflating: /content/Salt_Segmentation/train/images/f19b7d20bb.png
#   inflating: /content/Salt_Segmentation/train/images/62de954435.png
#   inflating: /content/Salt_Segmentation/train/images/d83a74a082.png
#   inflating: /content/Salt_Segmentation/train/images/f87154ea7b.png
#   inflating: /content/Salt_Segmentation/train/images/e335542c17.png
#   inflating: /content/Salt_Segmentation/train/images/c8bd99cbb0.png
#   inflating: /content/Salt_Segmentation/train/images/e4c8dc59fa.png
#   inflating: /content/Salt_Segmentation/train/images/3b5c0e9308.png
#   inflating: /content/Salt_Segmentation/train/images/4279e747a0.png
#   inflating: /content/Salt_Segmentation/train/images/246d86ba32.png
#   inflating: /content/Salt_Segmentation/train/images/ade746d346.png
#   inflating: /content/Salt_Segmentation/train/images/e5c26c8634.png
#   inflating: /content/Salt_Segmentation/train/images/6138f82415.png
#   inflating: /content/Salt_Segmentation/train/images/e927f91b12.png
#   inflating: /content/Salt_Segmentation/train/images/071c81c9ad.png
#   inflating: /content/Salt_Segmentation/train/images/2be45a7fa3.png
#   inflating: /content/Salt_Segmentation/train/images/6b996daecc.png
#   inflating: /content/Salt_Segmentation/train/images/5ad4b1d1ff.png
#   inflating: /content/Salt_Segmentation/train/images/2424f4afc7.png
#   inflating: /content/Salt_Segmentation/train/images/fe0ff502fb.png
#   inflating: /content/Salt_Segmentation/train/images/e1009fa370.png
#   inflating: /content/Salt_Segmentation/train/images/b76760a4a1.png
#   inflating: /content/Salt_Segmentation/train/images/68d9f77646.png
#   inflating: /content/Salt_Segmentation/train/images/93b8ec180f.png
#   inflating: /content/Salt_Segmentation/train/images/16589f0702.png
#   inflating: /content/Salt_Segmentation/train/images/25e519b494.png
#   inflating: /content/Salt_Segmentation/train/images/b966734278.png
#   inflating: /content/Salt_Segmentation/train/images/90c62cd13b.png
#   inflating: /content/Salt_Segmentation/train/images/ab767aef7f.png
#   inflating: /content/Salt_Segmentation/train/images/b83bc9dfa7.png
#   inflating: /content/Salt_Segmentation/train/images/26527458de.png
#   inflating: /content/Salt_Segmentation/train/images/e172f09faa.png
#   inflating: /content/Salt_Segmentation/train/images/4eccb0cb9d.png
#   inflating: /content/Salt_Segmentation/train/images/68bad6a787.png
#   inflating: /content/Salt_Segmentation/train/images/91127f8cc2.png
#   inflating: /content/Salt_Segmentation/train/images/b0a18e86c7.png
#   inflating: /content/Salt_Segmentation/train/images/25e4b6fd77.png
#   inflating: /content/Salt_Segmentation/train/images/da5ab3d506.png
#   inflating: /content/Salt_Segmentation/train/images/b095375d19.png
#   inflating: /content/Salt_Segmentation/train/images/9146f2afd1.png
#   inflating: /content/Salt_Segmentation/train/images/9cbd5ddba4.png
#   inflating: /content/Salt_Segmentation/train/images/dcca0c8297.png
#   inflating: /content/Salt_Segmentation/train/images/6010b9b84d.png
#   inflating: /content/Salt_Segmentation/train/images/821e0217f0.png
#   inflating: /content/Salt_Segmentation/train/images/7f2642a14a.png
#   inflating: /content/Salt_Segmentation/train/images/6caec01e67.png
#   inflating: /content/Salt_Segmentation/train/images/8a58fe70f8.png
#   inflating: /content/Salt_Segmentation/train/images/af0e101aae.png
#   inflating: /content/Salt_Segmentation/train/images/d93d713c55.png
#   inflating: /content/Salt_Segmentation/train/images/51846d4c96.png
#   inflating: /content/Salt_Segmentation/train/images/1ee82dabee.png
#   inflating: /content/Salt_Segmentation/train/images/481ed855f2.png
#   inflating: /content/Salt_Segmentation/train/images/edea91429d.png
#   inflating: /content/Salt_Segmentation/train/images/ffb2ad3f94.png
#   inflating: /content/Salt_Segmentation/train/images/a41357f553.png
#   inflating: /content/Salt_Segmentation/train/images/f6c784904d.png
#   inflating: /content/Salt_Segmentation/train/images/8d2e68312e.png
#   inflating: /content/Salt_Segmentation/train/images/6fc88fcbed.png
#   inflating: /content/Salt_Segmentation/train/images/96d917e53d.png
#   inflating: /content/Salt_Segmentation/train/images/4c4556fff0.png
#   inflating: /content/Salt_Segmentation/train/images/f1cdcb9883.png
#   inflating: /content/Salt_Segmentation/train/images/69013a70ab.png
#   inflating: /content/Salt_Segmentation/train/images/fadd701a33.png
#   inflating: /content/Salt_Segmentation/train/images/2c707479f9.png
#   inflating: /content/Salt_Segmentation/train/images/85bca2aade.png
#   inflating: /content/Salt_Segmentation/train/images/7f9f13c0d0.png
#   inflating: /content/Salt_Segmentation/train/images/d4d34af4f7.png
#   inflating: /content/Salt_Segmentation/train/images/f362d474b7.png
#   inflating: /content/Salt_Segmentation/train/images/869f99406d.png
#   inflating: /content/Salt_Segmentation/train/images/df8c73e52b.png
#   inflating: /content/Salt_Segmentation/train/images/77ecd76754.png
#   inflating: /content/Salt_Segmentation/train/images/e86361f5d1.png
#   inflating: /content/Salt_Segmentation/train/images/8164beeaf5.png
#   inflating: /content/Salt_Segmentation/train/images/3edc3edf92.png
#   inflating: /content/Salt_Segmentation/train/images/1a7f8bd454.png
#   inflating: /content/Salt_Segmentation/train/images/935cba59ad.png
#   inflating: /content/Salt_Segmentation/train/images/6b0688f33f.png
#   inflating: /content/Salt_Segmentation/train/images/c82dabf9b1.png
#   inflating: /content/Salt_Segmentation/train/images/7845115d01.png
#   inflating: /content/Salt_Segmentation/train/images/a6f4e0f8b5.png
#   inflating: /content/Salt_Segmentation/train/images/eab589e1f2.png
#   inflating: /content/Salt_Segmentation/train/images/f7ff576dc4.png
#   inflating: /content/Salt_Segmentation/train/images/7c6221dbb8.png
#   inflating: /content/Salt_Segmentation/train/images/38dfaadc68.png
#   inflating: /content/Salt_Segmentation/train/images/92d116836e.png
#   inflating: /content/Salt_Segmentation/train/images/94c94ee7b6.png
#   inflating: /content/Salt_Segmentation/train/images/2f746f8726.png
#   inflating: /content/Salt_Segmentation/train/images/0ddcd3fd1a.png
#   inflating: /content/Salt_Segmentation/train/images/e3e1afe993.png
#   inflating: /content/Salt_Segmentation/train/images/f7dc2b2c9a.png
#   inflating: /content/Salt_Segmentation/train/images/48d81e93d9.png
#   inflating: /content/Salt_Segmentation/train/images/df8caa8bdf.png
#   inflating: /content/Salt_Segmentation/train/images/3ee87f1ea6.png
#   inflating: /content/Salt_Segmentation/train/images/04182ced8e.png
#   inflating: /content/Salt_Segmentation/train/images/f456e3161d.png
#   inflating: /content/Salt_Segmentation/train/images/34b32c5b5d.png
#   inflating: /content/Salt_Segmentation/train/images/56ab4fae30.png
#   inflating: /content/Salt_Segmentation/train/images/106a222c7c.png
#   inflating: /content/Salt_Segmentation/train/images/4c8132dc73.png
#   inflating: /content/Salt_Segmentation/train/images/8174aba668.png
#   inflating: /content/Salt_Segmentation/train/images/dfd3138198.png
#   inflating: /content/Salt_Segmentation/train/images/a58d3b12bc.png
#   inflating: /content/Salt_Segmentation/train/images/0280db420c.png
#   inflating: /content/Salt_Segmentation/train/images/1401f04c4b.png
#   inflating: /content/Salt_Segmentation/train/images/52914952d6.png
#   inflating: /content/Salt_Segmentation/train/images/b9a7c521ac.png
#   inflating: /content/Salt_Segmentation/train/images/7db7a5fb8f.png
#   inflating: /content/Salt_Segmentation/train/images/0977568b54.png
#   inflating: /content/Salt_Segmentation/train/images/c4f5a0fa36.png
#   inflating: /content/Salt_Segmentation/train/images/ce15cc1d1a.png
#   inflating: /content/Salt_Segmentation/train/images/d369e6b550.png
#   inflating: /content/Salt_Segmentation/train/images/ad3c6dd8d4.png
#   inflating: /content/Salt_Segmentation/train/images/91c003779c.png
#   inflating: /content/Salt_Segmentation/train/images/6c45d80d1e.png
#   inflating: /content/Salt_Segmentation/train/images/44ccc2d846.png
#   inflating: /content/Salt_Segmentation/train/images/346358e652.png
#   inflating: /content/Salt_Segmentation/train/images/07ac7e530f.png
#   inflating: /content/Salt_Segmentation/train/images/217a70a0cb.png
#   inflating: /content/Salt_Segmentation/train/images/f1b1f57aee.png
#   inflating: /content/Salt_Segmentation/train/images/e875c9a960.png
#   inflating: /content/Salt_Segmentation/train/images/875b087f1c.png
#   inflating: /content/Salt_Segmentation/train/images/9fbd3ca3b5.png
#   inflating: /content/Salt_Segmentation/train/images/bab30e51b8.png
#   inflating: /content/Salt_Segmentation/train/images/a33fe0952a.png
#   inflating: /content/Salt_Segmentation/train/images/19cc342b91.png
#   inflating: /content/Salt_Segmentation/train/images/7053b28de2.png
#   inflating: /content/Salt_Segmentation/train/images/d6987190ea.png
#   inflating: /content/Salt_Segmentation/train/images/465486e6ec.png
#   inflating: /content/Salt_Segmentation/train/images/aebff18bf9.png
#   inflating: /content/Salt_Segmentation/train/images/3c1ed5cc1f.png
#   inflating: /content/Salt_Segmentation/train/images/efe3043924.png
#   inflating: /content/Salt_Segmentation/train/images/e73532b450.png
#   inflating: /content/Salt_Segmentation/train/images/9031ddc924.png
#   inflating: /content/Salt_Segmentation/train/images/ed20d93bfd.png
#   inflating: /content/Salt_Segmentation/train/images/c83d9529bd.png
#   inflating: /content/Salt_Segmentation/train/images/ceef85bdc0.png
#   inflating: /content/Salt_Segmentation/train/images/942d3bfbf3.png
#   inflating: /content/Salt_Segmentation/train/images/62715133c5.png
#   inflating: /content/Salt_Segmentation/train/images/c45c9617bf.png
#   inflating: /content/Salt_Segmentation/train/images/83c0564224.png
#   inflating: /content/Salt_Segmentation/train/images/9358b1fa7a.png
#   inflating: /content/Salt_Segmentation/train/images/debe560cfb.png
#   inflating: /content/Salt_Segmentation/train/images/939879034e.png
#   inflating: /content/Salt_Segmentation/train/images/80694aa70f.png
#   inflating: /content/Salt_Segmentation/train/images/c8d70d9c3d.png
#   inflating: /content/Salt_Segmentation/train/images/3577258d6b.png
#   inflating: /content/Salt_Segmentation/train/images/edf47afe46.png
#   inflating: /content/Salt_Segmentation/train/images/05c33e6854.png
#   inflating: /content/Salt_Segmentation/train/images/999ae650f6.png
#   inflating: /content/Salt_Segmentation/train/images/573f9f58c4.png
#   inflating: /content/Salt_Segmentation/train/images/6493c2cbab.png
#   inflating: /content/Salt_Segmentation/train/images/e7ee2c6dce.png
#   inflating: /content/Salt_Segmentation/train/images/492383a53b.png
#   inflating: /content/Salt_Segmentation/train/images/1d2c8152bd.png
#   inflating: /content/Salt_Segmentation/train/images/8db9dc4a62.png
#   inflating: /content/Salt_Segmentation/train/images/836eedd4a7.png
#   inflating: /content/Salt_Segmentation/train/images/fc250f574c.png
#   inflating: /content/Salt_Segmentation/train/images/e6caf5eb81.png
#   inflating: /content/Salt_Segmentation/train/images/dea0a56bab.png
#   inflating: /content/Salt_Segmentation/train/images/6da04e4c20.png
#   inflating: /content/Salt_Segmentation/train/images/5bf5d82829.png
#   inflating: /content/Salt_Segmentation/train/images/0a31d7553c.png
#   inflating: /content/Salt_Segmentation/train/images/25dc959ebd.png
#   inflating: /content/Salt_Segmentation/train/images/ed7251fc01.png
#   inflating: /content/Salt_Segmentation/train/images/fe85864f8f.png
#   inflating: /content/Salt_Segmentation/train/images/cd6ed7690d.png
#   inflating: /content/Salt_Segmentation/train/images/8e9f2b9b61.png
#   inflating: /content/Salt_Segmentation/train/images/20a0f53112.png
#   inflating: /content/Salt_Segmentation/train/images/212f074587.png
#   inflating: /content/Salt_Segmentation/train/images/5991bd3f1b.png
#   inflating: /content/Salt_Segmentation/train/images/c98504a8ab.png
#   inflating: /content/Salt_Segmentation/train/images/d7398cfded.png
#   inflating: /content/Salt_Segmentation/train/images/78c50b3977.png
#   inflating: /content/Salt_Segmentation/train/images/ae96972c1a.png
#   inflating: /content/Salt_Segmentation/train/images/5155ad847f.png
#   inflating: /content/Salt_Segmentation/train/images/af7e9d7648.png
#   inflating: /content/Salt_Segmentation/train/images/9b450671aa.png
#   inflating: /content/Salt_Segmentation/train/images/1770691c51.png
#   inflating: /content/Salt_Segmentation/train/images/3ca252f526.png
#   inflating: /content/Salt_Segmentation/train/images/4702cdd4f0.png
#   inflating: /content/Salt_Segmentation/train/images/768d5f7ade.png
#   inflating: /content/Salt_Segmentation/train/images/b858ccf692.png
#   inflating: /content/Salt_Segmentation/train/images/3d339265c4.png
#   inflating: /content/Salt_Segmentation/train/images/5a7a933a05.png
#   inflating: /content/Salt_Segmentation/train/images/84242f42bc.png
#   inflating: /content/Salt_Segmentation/train/images/fcce81906d.png
#   inflating: /content/Salt_Segmentation/train/images/24bf79cd1e.png
#   inflating: /content/Salt_Segmentation/train/images/6c3a9009c8.png
#   inflating: /content/Salt_Segmentation/train/images/7fc1ce1cb4.png
#   inflating: /content/Salt_Segmentation/train/images/8d839a365b.png
#   inflating: /content/Salt_Segmentation/train/images/5ec4b8eff9.png
#   inflating: /content/Salt_Segmentation/train/images/a803fc87d1.png
#   inflating: /content/Salt_Segmentation/train/images/0eb52aa52a.png
#   inflating: /content/Salt_Segmentation/train/images/52020f0fd4.png
#   inflating: /content/Salt_Segmentation/train/images/cb2acfd639.png
#   inflating: /content/Salt_Segmentation/train/images/13f3daf89f.png
#   inflating: /content/Salt_Segmentation/train/images/8e7324c8ed.png
#   inflating: /content/Salt_Segmentation/train/images/d8bed49320.png
#   inflating: /content/Salt_Segmentation/train/images/f507d4f122.png
#   inflating: /content/Salt_Segmentation/train/images/b4b225aaa8.png
#   inflating: /content/Salt_Segmentation/train/images/f870e41e88.png
#   inflating: /content/Salt_Segmentation/train/images/0461a2fb30.png
#   inflating: /content/Salt_Segmentation/train/images/7aa7e1b355.png
#   inflating: /content/Salt_Segmentation/train/images/85e6b4cb1c.png
#   inflating: /content/Salt_Segmentation/train/images/0a41de5e3b.png
#   inflating: /content/Salt_Segmentation/train/images/3c10a71f62.png
#   inflating: /content/Salt_Segmentation/train/images/1e5e713964.png
#   inflating: /content/Salt_Segmentation/train/images/6e409af2cb.png
#   inflating: /content/Salt_Segmentation/train/images/e37b8208fa.png
#   inflating: /content/Salt_Segmentation/train/images/212ba67b51.png
#   inflating: /content/Salt_Segmentation/train/images/1cc428e57e.png
#   inflating: /content/Salt_Segmentation/train/images/8d9b8d724a.png
#   inflating: /content/Salt_Segmentation/train/images/29b25b5f03.png
#   inflating: /content/Salt_Segmentation/train/images/570d1da727.png
#   inflating: /content/Salt_Segmentation/train/images/e73ed6e7f2.png
#   inflating: /content/Salt_Segmentation/train/images/21d01a8e82.png
#   inflating: /content/Salt_Segmentation/train/images/1c3397d0ef.png
#   inflating: /content/Salt_Segmentation/train/images/35499d9dd6.png
#   inflating: /content/Salt_Segmentation/train/images/29df15c1ce.png
#   inflating: /content/Salt_Segmentation/train/images/31683f8a18.png
#   inflating: /content/Salt_Segmentation/train/images/016fc8031c.png
#   inflating: /content/Salt_Segmentation/train/images/2ff32a1188.png
#   inflating: /content/Salt_Segmentation/train/images/c749d05181.png
#   inflating: /content/Salt_Segmentation/train/images/56b5540fd7.png
#   inflating: /content/Salt_Segmentation/train/images/e44dcaeb74.png
#   inflating: /content/Salt_Segmentation/train/masks/697fee88c5.png
#   inflating: /content/Salt_Segmentation/train/masks/21e1d6e38d.png
#   inflating: /content/Salt_Segmentation/train/masks/e7c55756c7.png
#   inflating: /content/Salt_Segmentation/train/masks/903180c447.png
#   inflating: /content/Salt_Segmentation/train/masks/8c99d8c85f.png
#   inflating: /content/Salt_Segmentation/train/masks/003c477d7c.png
#   inflating: /content/Salt_Segmentation/train/masks/c70153909b.png
#   inflating: /content/Salt_Segmentation/train/masks/ba1287cb48.png
#   inflating: /content/Salt_Segmentation/train/masks/3da64841d8.png
#   inflating: /content/Salt_Segmentation/train/masks/e060d5ca41.png
#   inflating: /content/Salt_Segmentation/train/masks/c038f6fbe4.png
#   inflating: /content/Salt_Segmentation/train/masks/d4033ae7f2.png
#   inflating: /content/Salt_Segmentation/train/masks/d67e3a11d8.png
#   inflating: /content/Salt_Segmentation/train/masks/690281a93d.png
#   inflating: /content/Salt_Segmentation/train/masks/62d30854d7.png
#   inflating: /content/Salt_Segmentation/train/masks/f0ec542987.png
#   inflating: /content/Salt_Segmentation/train/masks/5ec6db5c9d.png
#   inflating: /content/Salt_Segmentation/train/masks/0937b1df3f.png
#   inflating: /content/Salt_Segmentation/train/masks/3792be0845.png
#   inflating: /content/Salt_Segmentation/train/masks/52667992f8.png
#   inflating: /content/Salt_Segmentation/train/masks/203f6117be.png
#   inflating: /content/Salt_Segmentation/train/masks/95af8ca744.png
#   inflating: /content/Salt_Segmentation/train/masks/19902af6bd.png
#   inflating: /content/Salt_Segmentation/train/masks/c37e74bffc.png
#   inflating: /content/Salt_Segmentation/train/masks/f3356c9ee4.png
#   inflating: /content/Salt_Segmentation/train/masks/c26ff00bfd.png
#   inflating: /content/Salt_Segmentation/train/masks/c7ab9848b9.png
#   inflating: /content/Salt_Segmentation/train/masks/9b80cf8992.png
#   inflating: /content/Salt_Segmentation/train/masks/2ffe02e882.png
#   inflating: /content/Salt_Segmentation/train/masks/a0219e8fa4.png
#   inflating: /content/Salt_Segmentation/train/masks/730bddcc02.png
#   inflating: /content/Salt_Segmentation/train/masks/7ed0489985.png
#   inflating: /content/Salt_Segmentation/train/masks/7cc53fe88b.png

# %%
# !mkdir -p /content/Salt_Segmentation/test
# !unzip test.zip -d /content/Salt_Segmentation/test
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Salt_Segmentation/test/images/a3df74dd31.png
#   inflating: /content/Salt_Segmentation/test/images/187ecc32d5.png
#   inflating: /content/Salt_Segmentation/test/images/54538419f5.png
#   inflating: /content/Salt_Segmentation/test/images/93614d4b95.png
#   inflating: /content/Salt_Segmentation/test/images/50a91adce8.png
#   inflating: /content/Salt_Segmentation/test/images/97d23cea10.png
#   inflating: /content/Salt_Segmentation/test/images/ca04c19c0b.png
#   inflating: /content/Salt_Segmentation/test/images/d168218bac.png
#   inflating: /content/Salt_Segmentation/test/images/a670e833a4.png
#   inflating: /content/Salt_Segmentation/test/images/a964a0f499.png
#   inflating: /content/Salt_Segmentation/test/images/371bf59030.png
#   inflating: /content/Salt_Segmentation/test/images/fc74f77bae.png
#   inflating: /content/Salt_Segmentation/test/images/8688aa6acb.png
#   inflating: /content/Salt_Segmentation/test/images/830f5d9628.png
#   inflating: /content/Salt_Segmentation/test/images/fdc16dcadf.png
#   inflating: /content/Salt_Segmentation/test/images/a157bacfbe.png
#   inflating: /content/Salt_Segmentation/test/images/ba3558504f.png
#   inflating: /content/Salt_Segmentation/test/images/4c0f207a50.png
#   inflating: /content/Salt_Segmentation/test/images/086c242b55.png
#   inflating: /content/Salt_Segmentation/test/images/d20d6f41dd.png
#   inflating: /content/Salt_Segmentation/test/images/27f1c2b267.png
#   inflating: /content/Salt_Segmentation/test/images/0960ae5218.png
#   inflating: /content/Salt_Segmentation/test/images/752368df10.png
#   inflating: /content/Salt_Segmentation/test/images/6a436d7460.png
#   inflating: /content/Salt_Segmentation/test/images/5a01200b40.png
#   inflating: /content/Salt_Segmentation/test/images/7b1c5cf0c3.png
#   inflating: /content/Salt_Segmentation/test/images/be466f2fc3.png
#   inflating: /content/Salt_Segmentation/test/images/eaf3b0ec78.png
#   inflating: /content/Salt_Segmentation/test/images/10321b58c3.png
#   inflating: /content/Salt_Segmentation/test/images/1bbf1cdaba.png
#   inflating: /content/Salt_Segmentation/test/images/3d6e96149e.png

# %% [markdown]
# *   os: Modul za interakciju sa operativnim sistemom. Koristi se za manipulaciju putanjama datoteka i direktorijuma.
#
# *   random: Modul za generisanje slučajnih brojeva.
# *   time: Modul za rad sa vremenom i merenje vremenskih intervala.
# *   math: Modul za matematičke operacije i funkcije.
# *   glob: Modul za pretragu datoteka na osnovu zadatih kriterijuma.
# *   numpy as np: Biblioteka za numeričke operacije, posebno rad sa višedimenzionalnim nizovima.
# *   pandas: Biblioteka za manipulaciju i analizu podataka, posebno tabularnih podataka.
# *   matplotlib.pyplot: Biblioteka za vizualizaciju podataka, kao što su
# grafici i dijagrami.
# *  torch: Biblioteka za mašinsko učenje i duboko učenje.
# *   torch.nn: Modul koji sadrži različite klase za definisanje neuronskih mreža.
# *   torch.nn.functional: Modul koji sadrži različite funkcije aktivacije, gubitke i druge funkcije koje se često koriste u neuronskim mrežama.
# *   torchvision: Biblioteka koja pruža pristup popularnim skupovima podataka, modelima i transformacijama za kompjuterski vid.
# *   torchvision.transforms: Modul koji sadrži različite transformacije slika koje se koriste u kompjuterskom vidu.
# *   Dataset, DataLoader: Klase koje olakšavaju manipulaciju podacima prilikom obuke neuronskih mreža.
# *   Image: Modul koji pruža podršku za manipulaciju slikama.

# %%
import os
import random
import time
import math
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch

import torch.nn as nn
import torch.nn.functional as F

import torchvision
import torchvision.transforms as T

from torch.utils.data import Dataset, DataLoader

from PIL import Image

# %% [markdown]
# CUDA (engl. Compute Unified Device Architecture) je paralelna računarska platforma i API (engl. Application Programming Interface) koju je razvio NVIDIA za izvršavanje zahtevnih računarskih operacija na GPU-ima (engl.* Graphics Processing Units*).
#
# Postavljanje device-a na "cuda" omogućava korišćenje GPU-a za ubrzanje izračunavanja prilikom obuke i evaluacije neuronske mreže.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# SAMPLE_SUBMISSION_PATH = 'sample_submission.csv': Ovo je putanja do CSV datoteke koja sadrži uzorak (šablon) za podnošenje rezultata.
#
# MODEL_OUTPUT_PATH = 'unet_model.pth': Ovo je putanja do datoteke u kojoj će biti sačuvan model nakon obuke.

# %%
DATASET_PATH = '/content/Salt_Segmentation/'

IMAGE_TRAIN_PATH = os.path.join(DATASET_PATH, 'train/images')
MASK_TRAIN_PATH = os.path.join(DATASET_PATH, 'train/masks')
IMAGE_TEST_PATH = os.path.join(DATASET_PATH, 'test/images')

SAMPLE_SUBMISSION_PATH = 'sample_submission.csv'

MODEL_OUTPUT_PATH = 'unet_model.pth'

# %%
image_train = os.listdir(IMAGE_TRAIN_PATH)
mask_train = os.listdir(MASK_TRAIN_PATH)

# %% [markdown]
# Definisanje subplot-a sa 4 reda u 4 kolone, čime se kreira mreža za umetanje slika i omogućava kreiranje grafikona. Suština je transformacija slika u tenzore.
#
# transforms = T.Compose([T.Grayscale(), T.ToTensor()]): Definiše se transformacija koja će biti primenjena na sliku i masku. U ovom slučaju, transformacije uključuju konverziju u grayscale i konverziju u tenzor.
#
# image/mask = torch.stack([transforms(image/mask)]): Primenjuje se transformacija na sliku/masku i rezultat se smešta u tenzor. torch.stack() funkcija se koristi za dodavanje dodatne dimenzije tenzoru, kako bi odgovarao očekivanim dimenzijama ulaza za model.

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(12,12))

for i in range(4):
    r = random.randint(0, len(image_train) - 1)

    image = Image.open(os.path.join(IMAGE_TRAIN_PATH + '/{}'.format(image_train[r])))
    mask = Image.open(os.path.join(MASK_TRAIN_PATH + '/{}'.format(mask_train[r])))

    transforms = T.Compose([T.Grayscale(), T.ToTensor()])

    image = torch.stack([transforms(image)])
    mask = torch.stack([transforms(mask)])

    ax[i,0].imshow(image.squeeze(), cmap='Greys')
    ax[i,1].imshow(mask.squeeze(), cmap='Greys')
    ax[i,2].imshow(image.squeeze(), cmap='Greys')
    ax[i,2].imshow(mask.squeeze(), cmap='PuBu', alpha=0.7)

    ax[i,0].set_yticklabels([])
    ax[i,0].set_xticklabels([])
    ax[i,1].set_yticklabels([])
    ax[i,1].set_xticklabels([])
    ax[i,2].set_yticklabels([])
    ax[i,2].set_xticklabels([])

    ax[i,0].set_title('Image', loc='center')
    ax[i,1].set_title('Mask', loc='center')
    ax[i,2].set_title('Image + Mask', loc='center')

plt.show()

# %% [markdown]
# Klasa Segmentation_Dataset omogućava jednostavno učitavanje i transformaciju slika i maski za segmentaciju. Pomoću ovog dataset-a, može se koristiti i DataLoader za efikasno učitavanje podataka tokom obuke i evaluacije modela.

# %%
class Segmentation_Dataset(Dataset):
    def __init__(self, image_path, mask_path):
        self.image_path = image_path
        self.mask_path = mask_path

        images = glob.glob(image_path + '/*.png')

        samples = []

        for image in images:
            samples.append(image.split('/')[-1].split('.')[0])

        self.samples = samples

        self.transforms = T.Compose([T.Grayscale(), T.ToTensor()])

    def __getitem__(self, idx):
        image = Image.open(os.path.join(self.image_path, self.samples[idx] + '.png'))
        mask = Image.open(os.path.join(self.mask_path, self.samples[idx] + '.png'))

        return self.transforms(image), self.transforms(mask)

    def __len__(self):
        return len(self.samples)

# %%
train_dataset = Segmentation_Dataset(IMAGE_TRAIN_PATH, MASK_TRAIN_PATH)

# %% [markdown]
# ConovolutionBlock klasa se obično koristi za izgradnju složenijih arhitektura neuronskih mreža, gde se blokovi konvolucije ponavljaju kako bi se izgradila dublja mreža sa više kanala i slojeva.

# %%
class ConvolutionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, activation=True):
        super(ConvolutionBlock, self).__init__()

        self.activation = activation

        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride=stride, padding=kernel_size // 2)

        self.norm = nn.BatchNorm2d(out_channels)

    def forward(self, x):
        x = self.conv(x)
        x = self.norm(x)

        if self.activation:
            return F.relu(x)
        else:
            return x

# %% [markdown]
# Rezidualni blok omogućava neuronskoj mreži da "preskoči" slojeve i prenese informacije sa ulaza direktno na izlaz, čime se olakšava učenje i umanjuje problem nestajućeg gradijenta. Ovi blokovi se često koriste u dubokim arhitekturama kao što su ResNet i DenseNet.

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3):
        super(ResidualBlock, self).__init__()

        self.norm = nn.BatchNorm2d(in_channels)

        self.conv1 = ConvolutionBlock(in_channels, out_channels, kernel_size)
        self.conv2 = ConvolutionBlock(out_channels, out_channels, kernel_size, activation=False)

    def forward(self, x):
        residual = x

        x = F.relu(x)

        x = self.norm(x)
        x = self.conv1(x)
        x = self.conv2(x)

        return x

# %% [markdown]
# Blok Dekonvolucije se koristi za povećavanje rezolucije ulaznih slika. Na primer, može se koristiti za rekonstrukciju detalja koji su izgubljeni tokom downsamplinga u prethodnim slojevima mreže.

# %%
class DeconvolutionBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=2, stride=2):
        super(DeconvolutionBlock, self).__init__()

        self.deconv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride)

    def forward(self, x1, x2):
        xd = self.deconv(x1)

        x = torch.cat([xd,x2], dim=1)

        return x

# %% [markdown]
# Klasa UNet predstavlja implementaciju UNet arhitekture za segmentaciju slika. UNet je popularna arhitektura koja se često koristi u zadacima segmentacije slika, posebno za segmentaciju pojedinačnih objekata ili regiona unutar slike.

# %%
class UNet(nn.Module):
    def __init__(self, filters=16, dropout=0.5):
        super(UNet, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(1, filters, 3, padding=1),
            ResidualBlock(filters, filters),
            ResidualBlock(filters, filters),
            nn.ReLU()
        )

        self.conv2 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout / 2),
            nn.Conv2d(filters, filters * 2, 3, padding=1),
            ResidualBlock(filters * 2, filters * 2),
            ResidualBlock(filters * 2, filters * 2),
            nn.ReLU()
        )

        self.conv3 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 2, filters * 4, 3, padding=1),
            ResidualBlock(filters * 4, filters * 4),
            ResidualBlock(filters * 4, filters * 4),
            nn.ReLU()
        )

        self.conv4 = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 4, filters * 8, 3, padding=1),
            ResidualBlock(filters * 8, filters * 8),
            ResidualBlock(filters * 8, filters * 8),
            nn.ReLU()
        )

        self.middle = nn.Sequential(
            nn.MaxPool2d(2, 2),
            nn.Dropout(dropout),
            nn.Conv2d(filters * 8, filters * 16, 3, padding=3 // 2),
            ResidualBlock(filters * 16, filters * 16),
            ResidualBlock(filters * 16, filters * 16),
            nn.ReLU()
        )

        self.deconv4 = DeconvolutionBlock(filters * 16, filters * 8, 2)

        self.upconv4 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 16, filters * 8, 3, padding=1),
            ResidualBlock(filters * 8, filters * 8),
            ResidualBlock(filters * 8, filters * 8),
            nn.ReLU()
        )

        self.deconv3 = DeconvolutionBlock(filters * 8, filters * 4, 3)

        self.upconv3 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 8, filters * 4, 3, padding=1),
            ResidualBlock(filters * 4, filters * 4),
            ResidualBlock(filters * 4, filters * 4),
            nn.ReLU()
        )

        self.deconv2 = DeconvolutionBlock(filters * 4, filters * 2, 2)

        self.upconv2 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 4, filters * 2, 3, padding=1),
            ResidualBlock(filters * 2, filters * 2),
            ResidualBlock(filters * 2, filters * 2),
            nn.ReLU()
        )

        self.deconv1 = DeconvolutionBlock(filters * 2, filters, 3)

        self.upconv1 = nn.Sequential(
            nn.Dropout(dropout),
            nn.Conv2d(filters * 2, filters, 3, padding=1),
            ResidualBlock(filters, filters),
            ResidualBlock(filters, filters),
            nn.ReLU(),
            nn.Dropout(dropout / 2),
            nn.Conv2d(filters, 1, 3, padding=1)
        )

    def forward(self, x):
        conv1 = self.conv1(x)
        # 101 -> 50
        conv2 = self.conv2(conv1)
        # 50 -> 25
        conv3 = self.conv3(conv2)
        # 25 -> 12
        conv4 = self.conv4(conv3)
        # 12 - 6
        x = self.middle(conv4)
        # 6 -> 12
        x = self.deconv4(x, conv4)
        x = self.upconv4(x)
        # 12 -> 25
        x = self.deconv3(x, conv3)
        x = self.upconv3(x)
        # 25 -> 50
        x = self.deconv2(x, conv2)
        x = self.upconv2(x)
        # 50 -> 101
        x = self.deconv1(x, conv1)
        x = self.upconv1(x)

        return x

# %% [markdown]
# Funkcija iou_score(*outputs, labels*) predstavlja implementaciju izračunavanja 'Intersection over Union' (*IoU*) metrike za ocenu performansi segmentacije. IoU metrika se često koristi za ocenu kvaliteta segmentacije, gde vrednosti bliže 1 ukazuju na bolje rezultate.

# %%
def iou_score(outputs, labels):
    A = labels.squeeze().bool()

    pred = torch.where(outputs < 0., torch.zeros_like(outputs), torch.ones_like(outputs))

    B = pred.squeeze().bool()

    intersection = (A & B).float().sum((1,2))

    union = (A | B).float().sum((1,2))

    iou = (intersection + 1e-6) / (union + 1e-6)

    return iou

# %% [markdown]
# Funkcija train_one_batch(model, x, y) predstavlja jednu iteraciju treninga nad jednim mini-batch-om podataka. Ova funkcija se koristi tokom treninga kako bi se izvršila jedna iteracija (prosleđivanje ulaza kroz mrežu, izračunavanje gubitka, propagacija unazad, ažuriranje parametara).

# %%
def train_one_batch(model, x, y):
    x, y = x.to(device), y.to(device)

    outputs = model(x)

    loss = loss_fn(outputs, y)
    iou = iou_score(outputs, y).mean()

    optimizer.zero_grad()

    loss.backward()

    optimizer.step()

    return loss.item(), iou.item()

# %% [markdown]
# Ova funkcija se može koristiti za prikazivanje vremena proteklog od nekog trenutka kako bi se pratio napredak treninga ili izvršavanje nekog koda. Na primer, može se koristiti za prikazivanje koliko vremena je proteklo od početka treninga kao što je u ovom primeru.

# %%
def time_since(since):
    now = time.time()

    s = now - since
    m = math.floor(s / 60)
    s -= m * 60

    return '%dm %ds' % (m,s)

# %% [markdown]
# Glavna petlja obuhvata epohe i korake unutar svake epohe. U svakoj epohi, petlja prolazi kroz trening dataloader i izvršava funkciju train_one_batch za svaki batch. Nakon svakog koraka se prikazuju trenutni gubitak i IoU za taj korak.
#
# Na kraju svake epohe se prikazuju prosečni gubitak i IoU za tu epohu, kao i proteklo vreme od početka treninga.
#
# Takođe se koristi scheduler da bi se prilagodila stopa učenja na osnovu IoU vrednosti. Scheduler će smanjiti stopu učenja ako se IoU ne poboljšava.
#
# Na kraju petlje se dodaju vrednosti gubitka i IoU u odgovarajuće liste train_loss i train_iou.
#
# Ovaj kod se koristi za treniranje UNet modela na trening podacima u train_dataset.

# %%
NUM_EPOCHS = 7
BATCH_SIZE = 64

model = UNet().to(device)

model.train()

optimizer = torch.optim.Adam(model.parameters())
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'max')

loss_fn = nn.BCEWithLogitsLoss()

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

steps = train_dataset.__len__() // BATCH_SIZE

start = time.time()

train_loss = []

train_iou = []

for epoch in range(1, NUM_EPOCHS+1):
    print('Epoch {}/{}'.format(epoch, NUM_EPOCHS))

    running_iou = []
    running_loss = []

    for step, (x,y) in enumerate(train_dataloader):
        loss, iou = train_one_batch(model, x, y)

        running_iou.append(iou)
        running_loss.append(loss)

        print('\r{:6.1f} %\tloss {:8.4f}\tIoU {:8.4f}'.format(100 * (step + 1) / steps, loss, iou), end='')

    print('\r{:6.1f} %\tloss {:8.4f}\tIoU {:8.4f}\t{}'.format(100 * (step + 1) / steps, np.mean(running_loss), np.mean(running_iou), time_since(start)))

    scheduler.step(np.mean(running_iou))

    train_loss.append(loss)
    train_iou.append(iou)
# Out:
# Epoch 1/7
#  100.0 %	loss   0.4141	IoU   0.4276	14m 54s
# Epoch 2/7
#  100.0 %	loss   0.3074	IoU   0.5699	30m 19s
# Epoch 3/7
#  100.0 %	loss   0.2862	IoU   0.5707	45m 26s
# Epoch 4/7
#  100.0 %	loss   0.2696	IoU   0.5868	60m 22s
# Epoch 5/7
#  100.0 %	loss   0.2487	IoU   0.5906	75m 12s
# Epoch 6/7
#  100.0 %	loss   0.2325	IoU   0.6060	89m 58s
# Epoch 7/7
#  100.0 %	loss   0.2385	IoU   0.6115	104m 39s

# %% [markdown]
# Naredni kod prikazuje grafik gubitka i IoU tokom treninga, što može biti korisno za praćenje performansi modela i evaluaciju napretka tokom epoha.

# %%
plt.plot(train_loss, label='loss')
plt.plot(train_iou, label='IoU')

plt.xlabel('epoch')
plt.ylabel('metric')

plt.legend()

plt.show()

# %% [markdown]
# Ovim kodom se vrši čuvanje stanja modela na disku kako bi se kasnije moglo koristiti za ponovno učitavanje modela i nastavak treninga ili za upotrebu modela za predviđanja.

# %%
torch.save(model.cpu().state_dict(), MODEL_OUTPUT_PATH)

# %% [markdown]
# Prikazani kod služi za prikazivanje nekoliko slika iz trening skupa zajedno sa stvarnom maskom i predviđenom maskom.

# %%
trainiter = iter(train_dataloader)
images, masks = next(trainiter)

output = model(images)
pred = torch.where(output < 0., torch.zeros_like(output), torch.ones_like(output))
iou = iou_score(output, masks).numpy()

max_images = output.size(0)

grid_width = 8

grid_height = int(max_images / grid_width)

fig, axs = plt.subplots(grid_height, grid_width, figsize=(grid_width * 2,grid_height * 2))

for i, _data in enumerate(zip(images, masks, pred, iou)):
    image, mask, pred, iou = _data

    ax = axs[int(i / grid_width), i % grid_width]

    ax.imshow(image.squeeze(), cmap='Greys')
    ax.imshow(mask.squeeze(), cmap='PuBu', alpha=0.5)
    ax.imshow(pred.squeeze(), cmap='Reds', alpha=0.5)

    ax.set_title('IoU: ' + str(round(iou, 2)), loc='right')

    ax.set_yticklabels([])
    ax.set_xticklabels([])

plt.suptitle('Blue: mask, Red: predicted mask')

plt.show()

# %% [markdown]
# Rle_encode je funkcija za kodiranje Run-Length Encoding (*RLE*) formata. RLE je jednostavan format kompresije koji se često koristi za kodiranje binarnih maski.
#
# Transforms je objekat klase torchvision.transforms.Compose koji se koristi za definisanje transformacija koje se primenjuju na slike. U ovom slučaju, transformacije uključuju konverziju slika u grayscale format i konverziju u tenzore koristeći T.Grayscale() i T.ToTensor() transformacije redom.

# %%
def rle_encode(im):
    pixels = im.flatten(order='F')
    pixels = np.concatenate([[0], pixels, [0]])

    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1

    runs[1::2] -= runs[::2]

    return ' '.join(str(x) for x in runs)

transforms = T.Compose([T.Grayscale(), T.ToTensor()])

# %% [markdown]
# Ovaj kod učitava podatke iz CSV fajla SAMPLE_SUBMISSION_PATH i prolazi kroz svaki red u okviru podataka. Za svaki red, izvršava sledeće korake:
#
#
# *   Izvlači vrednost kolone 'id' za trenutni red i dodeljuje je promenljivoj sample.
# *   Učitava sliku koristeći putanju IMAGE_TEST_PATH i dodajući vrednost sample u ime fajla.
# *   Primenjuje definisane transformacije na učitanu sliku.
# *   Prosleđuje transformisanu sliku modelu kako bi dobila izlaz.
# *   Primjenjuje prag na izlaznom tenzoru kako bi dobio binarnu masku.
# *   Kodira binarnu masku koristeći funkciju rle_encode i dodaje rezultat u listu rle_mask.
#
# Na kraju, dodaje se nova kolona 'rle_mask' u okvir podataka sub_df, koja sadrži kodirane maske RLE.

# %%
sub_df = pd.read_csv(SAMPLE_SUBMISSION_PATH)

n = sub_df.shape[0]

rle_mask = []

for idx in range(n):
    sample = sub_df['id'][idx]

    image = Image.open(os.path.join(IMAGE_TEST_PATH + '/{}.png'.format(sample)))
    image = transforms(image)

    out = model(image.unsqueeze(0)).squeeze()

    pred = torch.where(out < 0., torch.zeros_like(out), torch.ones_like(out))

    rle_mask.append(rle_encode(pred.numpy()))

sub_df['rle_mask'] = rle_mask

# %% [markdown]
# Fajl "submission.csv" je uspešno kreiran. U ovom fajlu su sačuvani podaci okvira sub_df sa dodatom kolonom "rle_mask" koja sadrži kodirane maske RLE. Indeksi nisu uključeni u CSV fajl.

# %%
sub_df.to_csv('submission.csv', index=False)
